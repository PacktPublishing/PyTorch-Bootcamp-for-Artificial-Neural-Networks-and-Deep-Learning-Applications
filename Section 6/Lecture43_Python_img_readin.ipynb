# %%
# for inline image display inside notebook
# % matplotlib inline 
import numpy as np
from PIL import Image, ImageFont, ImageDraw
from PIL.ImageChops import add, subtract, multiply, difference, screen
import PIL.ImageStat as stat
from skimage.io import imread, imsave, imshow, show, imread_collection, imshow_collection
from skimage import color, viewer, exposure, img_as_float, data
from skimage.transform import SimilarityTransform, warp, swirl
from skimage.util import invert, random_noise, montage
import matplotlib.image as mpimg
import matplotlib.pylab as plt
from scipy.ndimage import affine_transform, zoom
from scipy import misc
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/viewer/utils/core.py:10: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   warn("Recommended matplotlib backend is `Agg` for full "

# %% [markdown]
# ### read the image

# %%
im = Image.open("../Python_opencv/IMG_4781.JPG") #provide the correct path

# %%
print(im.width, im.height, im.mode, im.format, type(im))
# Out:
# 3024 3024 RGB JPEG <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
im.show() # display the image

# %% [markdown]
# ### read in image with scipy

# %%
import imageio

# %%
im2 = imageio.imread('../Python_opencv/IMG_4781.JPG')

# %%
print(type(im2), im2.shape, im2.dtype)
# <class 'imageio.core.util.Image'> (225, 225, 3) uint8
# Out:
# <class 'imageio.core.util.Image'> (3024, 3024, 3) uint8

# %%
plt.imshow(im2), plt.axis('off'), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1c364c8208>,
#  (-0.5, 3023.5, 3023.5, -0.5),
#  None)

# %% [markdown]
# ### Read the image (matplotlib)

# %%
im2 = mpimg.imread("../Python_opencv/IMG_4781.JPG")  
# read the image from disk as a numpy ndarray

# %%
print(im2.shape, im2.dtype, type(im2)) ## 3 channels (RGB image)
# Out:
# (3024, 3024, 3) uint8 <class 'numpy.ndarray'>

# %%
plt.figure(figsize=(10,10))
plt.imshow(im2) # display the image
plt.axis('off')
plt.show()

# %% [markdown]
# ### Read in multiple images from a folder

# %%
import cv2
import glob

# %%
images = [cv2.imread(file) for file in glob.glob('../Python_opencv/*.tif')]

# %%
plt.imshow(images[0])

# %%
plt.imshow(images[1])

# %% [markdown]
# ### Read in files with different extensions

# %%
imdir = '../Python_opencv/'
ext = ['JPG', 'jpg', 'tif']    # Add image formats here

files = []
[files.extend(glob.glob(imdir + '*.' + e)) for e in ext]

images2 = [cv2.imread(file) for file in files]

# %%
plt.imshow(images2[0])

# %%
plt.imshow(images2[1])

# %%
plt.imshow(images2[2])
